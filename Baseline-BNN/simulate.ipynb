# %%
from __future__ import division, print_function
import time
import torch.utils.data
from torchvision import transforms, datasets
import argparse
import matplotlib
from src.Stochastic_Gradient_HMC_SA.model_binary import BNN_cat
from src.utils import *
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split

matplotlib.use('Agg')
import matplotlib.pyplot as plt

# %%
parser = argparse.ArgumentParser(description='Train Bayesian Neural Net on Simulated Dataset with Stochastic Gradient HMC')
parser.add_argument('--epochs', type=int, nargs='?', action='store', default=2000,
                    help='How many epochs to train. Default: 20.')
parser.add_argument('--sample_freq', type=int, nargs='?', action='store', default=1,
                    help='How many epochs pass between saving samples. Default: 2.')
parser.add_argument('--burn_in', type=int, nargs='?', action='store', default=40,
                    help='How many epochs to burn in for?. Default: 20.')
parser.add_argument('--lr', type=float, nargs='?', action='store', default=0.01,
                    help='learning rate. I recommend 1e-2. Default: 1e-2.')
parser.add_argument('--models_dir', type=str, nargs='?', action='store', default='SGHMC_models',
                    help='Where to save learnt weights and train vectors. Default: \'SGHMC_models\'.')
parser.add_argument('--results_dir', type=str, nargs='?', action='store', default='SGHMC_results',
                    help='Where to save learnt training plots. Default: \'SGHMC_results\'.')
args = parser.parse_args(args=[])

# %%
# Where to save models weights
models_dir = args.models_dir
# Where to save plots and error, accuracy vectors
results_dir = args.results_dir

mkdir(models_dir)
mkdir(results_dir)
# ------------------------------------------------------------------------------------------------------
# train config
NTrainPoints = 800
batch_size = 32
nb_epochs = args.epochs
log_interval = 1
nb_its_dev = log_interval
flat_ims=True
# ------------------------------------------------------------------------------------------------------
# dataset
cprint('c', '\nData:')

# load data

class CustomNNDataset(Dataset):
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __len__(self):
        return len(self.x)

    def __getitem__(self, idx):
        x = self.x[idx]
        y = self.y[idx]
        return x, y

with open(os.path.join('./nn.pickle'), 'rb') as f:
  [pr_cov,x,true_input,y] = pickle.load(f)

use_cuda = torch.cuda.is_available()


x = torch.from_numpy(x).type(torch.float)
y = torch.from_numpy(y).type(torch.int).reshape(y.shape[0],)

# split the data into training and validation sets
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.2, random_state=42)

# define the train and validation sets
train_dataset = CustomNNDataset(x_train, y_train)
val_dataset = CustomNNDataset(x_val, y_val)
all_dataset = CustomNNDataset(x, y)

# test set
with open(os.path.join('./nn_test.pickle'), 'rb') as f:
  [pr_cov_test,x_test,true_input_test,y_test] = pickle.load(f)
x_test = torch.from_numpy(x_test).type(torch.float)
y_test = torch.from_numpy(y_test).type(torch.int).reshape(y_test.shape[0],)
test_dataset = CustomNNDataset(x_test, y_test)


if use_cuda:
    trainloader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True, pin_memory=True,
                                              num_workers=3)
    valloader = torch.utils.data.DataLoader(all_dataset, batch_size=batch_size, shuffle=False, pin_memory=True,
                                            num_workers=3)

else:
    trainloader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True, pin_memory=False,
                                              num_workers=3)
    valloader = torch.utils.data.DataLoader(all_dataset, batch_size=batch_size, shuffle=False, pin_memory=False,
                                            num_workers=3)
# Out:
# Data:

# %%
## ---------------------------------------------------------------------------------------------------------------------
# net dims
cprint('c', '\nNetwork:')
from collections import OrderedDict
lr = args.lr
########################################################################################

import torch
net = BNN_cat(NTrainPoints, lr=lr, cuda=False, grad_std_mul=20)
burn_in = args.burn_in
sim_steps = args.sample_freq
N_saves=100000
resample_its = 50
resample_prior_its = 15
re_burn = 1e8


epoch = 0
it_count = 0
## ----------------------------------------------------------------------------------------
# train
cprint('c', '\nTrain:')

print('  init cost variables:')
cost_train = np.zeros(nb_epochs)
err_train = np.zeros(nb_epochs)
cost_dev = np.zeros(nb_epochs)
err_dev = np.zeros(nb_epochs)
best_cost = np.inf
best_err = np.inf
test_accuracy_dev = np.zeros(nb_epochs)


probs_dev = np.zeros([nb_epochs, 1000])
_dev = np.zeros([nb_epochs, 1000])

tic0 = time.time()
for i in range(epoch, nb_epochs):
    net.set_mode_train(True)
    tic = time.time()
    nb_samples = 0
    for x, y in trainloader:

        if flat_ims:
            x = x.view(x.shape[0], -1)
            y = y.unsqueeze(1)

        cost_pred, err = net.fit(x, y, burn_in=(i % re_burn < burn_in),
                                 resample_momentum=(it_count % resample_its == 0),
                                 resample_prior=(it_count % resample_prior_its == 0))
        it_count += 1
        err_train[i] += err
        cost_train[i] += cost_pred
        nb_samples += len(x)

    cost_train[i] /= nb_samples
    err_train[i] /= nb_samples
    toc = time.time()

    # ---- print
    print("it %d/%d, Jtr_pred = %f, err = %f, " % (i, nb_epochs, cost_train[i], err_train[i]), end="")
    cprint('r', '   time: %f seconds\n' % (toc - tic))
    net.update_lr(i)

    # ---- save weights
    if i % re_burn >= burn_in and i % sim_steps == 0:
        net.save_sampled_net(max_samples=N_saves)

    # ---- dev
    if i % nb_its_dev == 0:
        nb_samples = 0
        for j, (x, y) in enumerate(valloader):
            if flat_ims:
                x = x.view(x.shape[0], -1)
                y = y.unsqueeze(1)

            cost, err, probs = net.eval(x, y)

            cost_dev[i] += cost
            err_dev[i] += err
            nb_samples += len(x)
            probs_dev[i, batch_size*j : batch_size*j + len(y)] = probs.view(-1)

        cost_dev[i] /= nb_samples
        err_dev[i] /= nb_samples

        cprint('g', '    Jdev = %f, err = %f\n' % (cost_dev[i], err_dev[i]))
        if err_dev[i] < best_err:
            best_err = err_dev[i]
            cprint('b', 'best test error')

    test_accuracy = 1 - net.eval(test_dataset.x, test_dataset.y.unsqueeze(1))[1].numpy() / test_dataset.y.shape[0]
    test_accuracy_dev[i] = test_accuracy

toc0 = time.time()
runtime_per_it = (toc0 - tic0) / float(nb_epochs)
runtime_total = toc0 - tic0
cprint('r', '   average time: %f seconds\n' % runtime_per_it)
cprint('r', '   total time: %f seconds\n' % runtime_total)

## SAVE WEIGHTS
net.save_weights(models_dir + '/state_dicts.pkl')

save_object(probs_dev, models_dir + '/probs.pkl')
# Out:
# Network:
#
# Net:
# BNN categorical output
#     Total params: 0.00M
#
# Train:
#   init cost variables:
# it 0/2000, Jtr_pred = 0.476476, err = 0.280000,    time: 0.231317 seconds
#
#  saving weight samples 1/100000
#     Jdev = 0.208839, err = 0.054000
#
# best test error
# it 1/2000, Jtr_pred = 0.225960, err = 0.068750,    time: 0.215816 seconds
#
#  saving weight samples 2/100000
#     Jdev = 0.177885, err = 0.052000
#
# best test error
# it 2/2000, Jtr_pred = 0.202164, err = 0.058750,    time: 0.233400 seconds
#
#  saving weight samples 3/100000
#     Jdev = 0.166427, err = 0.049000
#
# best test error
# it 3/2000, Jtr_pred = 0.200617, err = 0.061250,    time: 0.246078 seconds
#
#  saving weight samples 4/100000
#     Jdev = 0.171181, err = 0.056000
#
# it 4/2000, Jtr_pred = 0.186485, err = 0.058750,    time: 0.231210 seconds
#
#  saving weight samples 5/100000
#     Jdev = 0.155423, err = 0.048000
#
# best test error
# it 5/2000, Jtr_pred = 0.169900, err = 0.050000,    time: 0.238800 seconds
#
#  saving weight samples 6/100000
#     Jdev = 0.144281, err = 0.045000
#
# best test error
# it 6/2000, Jtr_pred = 0.173380, err = 0.056250,    time: 0.243852 seconds
#
#  saving weight samples 7/100000
#     Jdev = 0.144027, err = 0.043000
#
# best test error
# it 7/2000, Jtr_pred = 0.181347, err = 0.061250,    time: 0.241159 seconds
#
#  saving weight samples 8/100000
#     Jdev = 0.144273, err = 0.040000
#
# best test error
# it 8/2000, Jtr_pred = 0.148772, err = 0.047500,    time: 0.229707 seconds
#
#  saving weight samples 9/100000
#     Jdev = 0.124690, err = 0.036000
#
# best test error
# it 9/2000, Jtr_pred = 0.141199, err = 0.043750,    time: 0.230453 seconds
#
#  saving weight samples 10/100000
#     Jdev = 0.138718, err = 0.042000
#
# it 10/2000, Jtr_pred = 0.142750, err = 0.046250,    time: 0.234287 seconds
#
#  saving weight samples 11/100000
#     Jdev = 0.120203, err = 0.034000
#
# best test error
# it 11/2000, Jtr_pred = 0.132702, err = 0.035000,    time: 0.229877 seconds
#
#  saving weight samples 12/100000
#     Jdev = 0.115766, err = 0.029000
#
# best test error
# it 12/2000, Jtr_pred = 0.127575, err = 0.033750,    time: 0.229141 seconds
#
#  saving weight samples 13/100000
#     Jdev = 0.123006, err = 0.034000
#
# it 13/2000, Jtr_pred = 0.136652, err = 0.033750,    time: 0.227306 seconds
#
#  saving weight samples 14/100000
#     Jdev = 0.133404, err = 0.040000
#
# it 14/2000, Jtr_pred = 0.140236, err = 0.040000,    time: 0.241544 seconds
#
#  saving weight samples 15/100000
#     Jdev = 0.144499, err = 0.040000
#
# it 15/2000, Jtr_pred = 0.172332, err = 0.051250,    time: 0.235608 seconds
#
#  saving weight samples 16/100000
#     Jdev = 0.175275, err = 0.049000
#
# it 16/2000, Jtr_pred = 0.178291, err = 0.052500,    time: 0.226242 seconds
#
#  saving weight samples 17/100000
#     Jdev = 0.135197, err = 0.038000
#
# it 17/2000, Jtr_pred = 0.154193, err = 0.041250,    time: 0.233796 seconds
#
#  saving weight samples 18/100000
#     Jdev = 0.108578, err = 0.031000
#
# it 18/2000, Jtr_pred = 0.138311, err = 0.043750,    time: 0.229057 seconds
#
#  saving weight samples 19/100000
#     Jdev = 0.149081, err = 0.046000
#
# it 19/2000, Jtr_pred = 0.130557, err = 0.038750,    time: 0.243364 seconds
#
#  saving weight samples 20/100000
#     Jdev = 0.104286, err = 0.031000
#
# it 20/2000, Jtr_pred = 0.115317, err = 0.032500,    time: 0.239336 seconds
#
#  saving weight samples 21/100000
#     Jdev = 0.107185, err = 0.031000
#
# it 21/2000, Jtr_pred = 0.138178, err = 0.037500,    time: 0.228845 seconds
#
#  saving weight samples 22/100000
#     Jdev = 0.112574, err = 0.030000
#
# it 22/2000, Jtr_pred = 0.117356, err = 0.031250,    time: 0.248271 seconds
#
#  saving weight samples 23/100000
#     Jdev = 0.107856, err = 0.032000
#
# it 23/2000, Jtr_pred = 0.123910, err = 0.040000,    time: 0.234866 seconds
#
#  saving weight samples 24/100000
#     Jdev = 0.129796, err = 0.038000
#
# it 24/2000, Jtr_pred = 0.115083, err = 0.033750,    time: 0.232595 seconds
#
#  saving weight samples 25/100000
#     Jdev = 0.102618, err = 0.031000
#
# it 25/2000, Jtr_pred = 0.116108, err = 0.033750,    time: 0.229723 seconds
#
#  saving weight samples 26/100000
#     Jdev = 0.101364, err = 0.031000
#
# it 26/2000, Jtr_pred = 0.114484, err = 0.036250,    time: 0.233263 seconds
#
#  saving weight samples 27/100000
#     Jdev = 0.100832, err = 0.029000
#
# it 27/2000, Jtr_pred = 0.123164, err = 0.040000,    time: 0.228256 seconds
#
#  saving weight samples 28/100000
#     Jdev = 0.107912, err = 0.028000
#
# best test error
# it 28/2000, Jtr_pred = 0.125154, err = 0.038750,    time: 0.238469 seconds
#
#  saving weight samples 29/100000
#     Jdev = 0.120469, err = 0.035000
#
# it 29/2000, Jtr_pred = 0.136755, err = 0.045000,    time: 0.227640 seconds
#
#  saving weight samples 30/100000
#     Jdev = 0.126882, err = 0.040000
#
# it 30/2000, Jtr_pred = 0.127107, err = 0.041250,    time: 0.232776 seconds
#
#  saving weight samples 31/100000
#     Jdev = 0.102097, err = 0.026000
#
# best test error
# it 31/2000, Jtr_pred = 0.122618, err = 0.033750,    time: 0.233888 seconds
#
#  saving weight samples 32/100000
#     Jdev = 0.109097, err = 0.027000
#
# it 32/2000, Jtr_pred = 0.112879, err = 0.027500,    time: 0.231964 seconds
#
#  saving weight samples 33/100000
#     Jdev = 0.109603, err = 0.032000
#
# it 33/2000, Jtr_pred = 0.119804, err = 0.035000,    time: 0.230044 seconds
#
#  saving weight samples 34/100000
#     Jdev = 0.106363, err = 0.027000
#
# it 34/2000, Jtr_pred = 0.111377, err = 0.033750,    time: 0.246024 seconds
#
#  saving weight samples 35/100000
#     Jdev = 0.105673, err = 0.024000
#
# best test error
# it 35/2000, Jtr_pred = 0.110018, err = 0.028750,    time: 0.244642 seconds
#
#  saving weight samples 36/100000
#     Jdev = 0.083393, err = 0.028000
#
# it 36/2000, Jtr_pred = 0.130074, err = 0.042500,    time: 0.235011 seconds
#
#  saving weight samples 37/100000
#     Jdev = 0.106465, err = 0.029000
#
# it 37/2000, Jtr_pred = 0.146805, err = 0.045000,    time: 0.229893 seconds
#
#  saving weight samples 38/100000
#     Jdev = 0.140031, err = 0.050000
#
# it 38/2000, Jtr_pred = 0.141236, err = 0.050000,    time: 0.234078 seconds
#
#  saving weight samples 39/100000
#     Jdev = 0.122960, err = 0.038000
#
# it 39/2000, Jtr_pred = 0.129090, err = 0.038750,    time: 0.234764 seconds
#
#  saving weight samples 40/100000
#     Jdev = 0.107028, err = 0.029000
#
# it 40/2000, Jtr_pred = 0.122738, err = 0.042500,    time: 0.438649 seconds
#
#  saving weight samples 41/100000
#     Jdev = 0.108701, err = 0.034000
#
# it 41/2000, Jtr_pred = 0.118325, err = 0.033750,    time: 0.394553 seconds
#
#  saving weight samples 42/100000
#     Jdev = 0.132249, err = 0.036000
#
# it 42/2000, Jtr_pred = 0.142278, err = 0.038750,    time: 0.407975 seconds
#
#  saving weight samples 43/100000
#     Jdev = 0.120991, err = 0.036000
#
# it 43/2000, Jtr_pred = 0.129239, err = 0.042500,    time: 0.408992 seconds
#
#  saving weight samples 44/100000
#     Jdev = 0.129520, err = 0.043000
#
# it 44/2000, Jtr_pred = 0.131820, err = 0.042500,    time: 0.392505 seconds
#
#  saving weight samples 45/100000
#     Jdev = 0.110164, err = 0.032000
#
# it 45/2000, Jtr_pred = 0.130234, err = 0.041250,    time: 0.398497 seconds
#
#  saving weight samples 46/100000
#     Jdev = 0.098946, err = 0.028000
#
# it 46/2000, Jtr_pred = 0.109662, err = 0.028750,    time: 0.396163 seconds
#
#  saving weight samples 47/100000
#     Jdev = 0.102817, err = 0.031000
#
# it 47/2000, Jtr_pred = 0.110467, err = 0.031250,    time: 0.395847 seconds
#
#  saving weight samples 48/100000
#     Jdev = 0.102083, err = 0.031000
#
# it 48/2000, Jtr_pred = 0.107993, err = 0.031250,    time: 0.404882 seconds
#
#  saving weight samples 49/100000
#     Jdev = 0.092289, err = 0.026000
#
# it 49/2000, Jtr_pred = 0.107367, err = 0.032500,    time: 0.393914 seconds
#
#  saving weight samples 50/100000
#     Jdev = 0.102335, err = 0.024000
#
# it 50/2000, Jtr_pred = 0.102253, err = 0.032500,    time: 0.406415 seconds
#
#  saving weight samples 51/100000
#     Jdev = 0.089652, err = 0.025000
#
# it 51/2000, Jtr_pred = 0.109883, err = 0.032500,    time: 0.393121 seconds
#
#  saving weight samples 52/100000
#     Jdev = 0.099039, err = 0.026000
#
# it 52/2000, Jtr_pred = 0.116883, err = 0.030000,    time: 0.473178 seconds
#
#  saving weight samples 53/100000
#     Jdev = 0.101109, err = 0.022000
#
# best test error
# it 53/2000, Jtr_pred = 0.107027, err = 0.030000,    time: 0.388290 seconds
#
#  saving weight samples 54/100000
#     Jdev = 0.111467, err = 0.026000
#
# it 54/2000, Jtr_pred = 0.106935, err = 0.030000,    time: 0.439043 seconds
#
#  saving weight samples 55/100000
#     Jdev = 0.099320, err = 0.028000
#
# it 55/2000, Jtr_pred = 0.118780, err = 0.033750,    time: 0.393339 seconds
#
#  saving weight samples 56/100000
#     Jdev = 0.103917, err = 0.031000
#
# it 56/2000, Jtr_pred = 0.124755, err = 0.037500,    time: 0.446255 seconds
#
#  saving weight samples 57/100000
#     Jdev = 0.130434, err = 0.039000
#
# it 57/2000, Jtr_pred = 0.131602, err = 0.042500,    time: 0.396111 seconds
#
#  saving weight samples 58/100000
#     Jdev = 0.098765, err = 0.028000
#
# it 58/2000, Jtr_pred = 0.120384, err = 0.038750,    time: 0.402726 seconds
#
#  saving weight samples 59/100000
#     Jdev = 0.101057, err = 0.032000
#
# it 59/2000, Jtr_pred = 0.145635, err = 0.052500,    time: 0.394857 seconds
#
#  saving weight samples 60/100000
#     Jdev = 0.156238, err = 0.065000
#
# it 60/2000, Jtr_pred = 0.120894, err = 0.041250,    time: 0.404480 seconds
#
#  saving weight samples 61/100000
#     Jdev = 0.131948, err = 0.029000
#
# it 61/2000, Jtr_pred = 0.124292, err = 0.037500,    time: 0.427933 seconds
#
#  saving weight samples 62/100000
#     Jdev = 0.115255, err = 0.036000
#
# it 62/2000, Jtr_pred = 0.131397, err = 0.042500,    time: 0.608706 seconds
#
#  saving weight samples 63/100000
#     Jdev = 0.113226, err = 0.034000
#
# it 63/2000, Jtr_pred = 0.113597, err = 0.033750,    time: 0.398350 seconds
#
#  saving weight samples 64/100000
#     Jdev = 0.109511, err = 0.029000
#
# it 64/2000, Jtr_pred = 0.123213, err = 0.037500,    time: 0.395774 seconds
#
#  saving weight samples 65/100000
#     Jdev = 0.116487, err = 0.034000
#
# it 65/2000, Jtr_pred = 0.109129, err = 0.037500,    time: 0.404263 seconds
#
#  saving weight samples 66/100000
#     Jdev = 0.105105, err = 0.030000
#
# it 66/2000, Jtr_pred = 0.121139, err = 0.035000,    time: 0.391734 seconds
#
#  saving weight samples 67/100000
#     Jdev = 0.111453, err = 0.031000
#
# it 67/2000, Jtr_pred = 0.118886, err = 0.036250,    time: 0.389920 seconds
#
#  saving weight samples 68/100000
#     Jdev = 0.135753, err = 0.036000
#
# it 68/2000, Jtr_pred = 0.120114, err = 0.041250,    time: 0.388495 seconds
#
#  saving weight samples 69/100000
#     Jdev = 0.128267, err = 0.042000
#
# it 69/2000, Jtr_pred = 0.129859, err = 0.042500,    time: 0.393470 seconds
#
#  saving weight samples 70/100000
#     Jdev = 0.118536, err = 0.037000
#
# it 70/2000, Jtr_pred = 0.117927, err = 0.031250,    time: 0.389867 seconds
#
#  saving weight samples 71/100000
#     Jdev = 0.101414, err = 0.031000
#
# it 71/2000, Jtr_pred = 0.124323, err = 0.040000,    time: 0.398425 seconds
#
#  saving weight samples 72/100000
#     Jdev = 0.112339, err = 0.034000
#
# it 72/2000, Jtr_pred = 0.130839, err = 0.037500,    time: 0.411840 seconds
#
#  saving weight samples 73/100000
#     Jdev = 0.119948, err = 0.038000
#
# it 73/2000, Jtr_pred = 0.144017, err = 0.046250,    time: 0.384528 seconds
#
#  saving weight samples 74/100000
#     Jdev = 0.129122, err = 0.043000
#
# it 74/2000, Jtr_pred = 0.132378, err = 0.042500,    time: 0.477691 seconds
#
#  saving weight samples 75/100000
#     Jdev = 0.103178, err = 0.028000
#
# it 75/2000, Jtr_pred = 0.118166, err = 0.038750,    time: 0.390572 seconds
#
#  saving weight samples 76/100000
#     Jdev = 0.105516, err = 0.026000
#
# it 76/2000, Jtr_pred = 0.115400, err = 0.036250,    time: 0.388505 seconds
#
#  saving weight samples 77/100000
#     Jdev = 0.098724, err = 0.024000
#
# it 77/2000, Jtr_pred = 0.117528, err = 0.032500,    time: 0.389226 seconds
#
#  saving weight samples 78/100000
#     Jdev = 0.099692, err = 0.029000
#
# it 78/2000, Jtr_pred = 0.104713, err = 0.030000,    time: 0.389740 seconds
#
#  saving weight samples 79/100000
#     Jdev = 0.098281, err = 0.028000
#
# it 79/2000, Jtr_pred = 0.117270, err = 0.038750,    time: 0.384655 seconds
#
#  saving weight samples 80/100000
#     Jdev = 0.101409, err = 0.032000
#
# it 80/2000, Jtr_pred = 0.106734, err = 0.032500,    time: 0.399972 seconds
#
#  saving weight samples 81/100000
#     Jdev = 0.099192, err = 0.031000
#
# it 81/2000, Jtr_pred = 0.111043, err = 0.033750,    time: 0.390965 seconds
#
#  saving weight samples 82/100000
#     Jdev = 0.101721, err = 0.028000
#
# it 82/2000, Jtr_pred = 0.111840, err = 0.031250,    time: 0.475538 seconds
#
#  saving weight samples 83/100000
#     Jdev = 0.099561, err = 0.027000
#
# it 83/2000, Jtr_pred = 0.127824, err = 0.035000,    time: 0.405595 seconds
#
#  saving weight samples 84/100000
#     Jdev = 0.105271, err = 0.028000
#
# it 84/2000, Jtr_pred = 0.120168, err = 0.037500,    time: 0.389775 seconds
#
#  saving weight samples 85/100000
#     Jdev = 0.115155, err = 0.036000
#
# it 85/2000, Jtr_pred = 0.124753, err = 0.040000,    time: 0.391849 seconds
#
#  saving weight samples 86/100000
#     Jdev = 0.118534, err = 0.031000
#
# it 86/2000, Jtr_pred = 0.119430, err = 0.041250,    time: 0.529688 seconds
#
#  saving weight samples 87/100000
#     Jdev = 0.117207, err = 0.038000
#
# it 87/2000, Jtr_pred = 0.124656, err = 0.040000,    time: 0.388686 seconds
#
#  saving weight samples 88/100000
#     Jdev = 0.112970, err = 0.034000
#
# it 88/2000, Jtr_pred = 0.117186, err = 0.035000,    time: 0.387417 seconds
#
#  saving weight samples 89/100000
#     Jdev = 0.103117, err = 0.032000
#
# it 89/2000, Jtr_pred = 0.137784, err = 0.033750,    time: 0.387311 seconds
#
#  saving weight samples 90/100000
#     Jdev = 0.119160, err = 0.029000
#
# it 90/2000, Jtr_pred = 0.127605, err = 0.035000,    time: 0.405785 seconds
#
#  saving weight samples 91/100000
#     Jdev = 0.101347, err = 0.030000
#
# it 91/2000, Jtr_pred = 0.127706, err = 0.043750,    time: 0.390742 seconds
#
#  saving weight samples 92/100000
#     Jdev = 0.117435, err = 0.036000
#
# it 92/2000, Jtr_pred = 0.114333, err = 0.035000,    time: 0.390743 seconds
#
#  saving weight samples 93/100000
#     Jdev = 0.114893, err = 0.033000
#
# it 93/2000, Jtr_pred = 0.122030, err = 0.036250,    time: 0.393036 seconds
#
#  saving weight samples 94/100000
#     Jdev = 0.109545, err = 0.034000
#
# it 94/2000, Jtr_pred = 0.115612, err = 0.037500,    time: 0.393525 seconds
#
#  saving weight samples 95/100000
#     Jdev = 0.112430, err = 0.030000
#
# it 95/2000, Jtr_pred = 0.127280, err = 0.035000,    time: 0.390212 seconds
#
#  saving weight samples 96/100000
#     Jdev = 0.105151, err = 0.031000
#
# it 96/2000, Jtr_pred = 0.112322, err = 0.030000,    time: 0.400373 seconds
#
#  saving weight samples 97/100000
#     Jdev = 0.102917, err = 0.031000
#
# it 97/2000, Jtr_pred = 0.111588, err = 0.036250,    time: 0.391252 seconds
#
#  saving weight samples 98/100000
#     Jdev = 0.116915, err = 0.034000
#
# it 98/2000, Jtr_pred = 0.131473, err = 0.047500,    time: 0.392610 seconds
#
#  saving weight samples 99/100000
#     Jdev = 0.112747, err = 0.036000
#
# it 99/2000, Jtr_pred = 0.115193, err = 0.037500,    time: 0.386424 seconds
#
#  saving weight samples 100/100000
#     Jdev = 0.105798, err = 0.031000
#
# it 100/2000, Jtr_pred = 0.110809, err = 0.036250,    time: 0.383829 seconds
#
#  saving weight samples 101/100000
#     Jdev = 0.109759, err = 0.033000
#
# it 101/2000, Jtr_pred = 0.123413, err = 0.038750,    time: 0.389806 seconds
#
#  saving weight samples 102/100000
#     Jdev = 0.105289, err = 0.034000
#
# it 102/2000, Jtr_pred = 0.110741, err = 0.033750,    time: 0.390765 seconds
#
#  saving weight samples 103/100000
#     Jdev = 0.102098, err = 0.028000
#
# it 103/2000, Jtr_pred = 0.105251, err = 0.031250,    time: 0.392218 seconds
#
#  saving weight samples 104/100000
#     Jdev = 0.094798, err = 0.027000
#
# it 104/2000, Jtr_pred = 0.118372, err = 0.037500,    time: 0.404774 seconds
#
#  saving weight samples 105/100000
#     Jdev = 0.104918, err = 0.029000
#
# it 105/2000, Jtr_pred = 0.136792, err = 0.045000,    time: 0.387771 seconds
#
#  saving weight samples 106/100000
#     Jdev = 0.106670, err = 0.032000
#
# it 106/2000, Jtr_pred = 0.112525, err = 0.033750,    time: 0.390257 seconds
#
#  saving weight samples 107/100000
#     Jdev = 0.112120, err = 0.033000
#
# it 107/2000, Jtr_pred = 0.133094, err = 0.042500,    time: 0.386082 seconds
#
#  saving weight samples 108/100000
#     Jdev = 0.109242, err = 0.035000
#
# it 108/2000, Jtr_pred = 0.111952, err = 0.036250,    time: 0.469247 seconds
#
#  saving weight samples 109/100000
#     Jdev = 0.104338, err = 0.033000
#
# it 109/2000, Jtr_pred = 0.115471, err = 0.036250,    time: 0.429614 seconds
#
#  saving weight samples 110/100000
#     Jdev = 0.106561, err = 0.034000
#
# it 110/2000, Jtr_pred = 0.114832, err = 0.042500,    time: 0.527079 seconds
#
#  saving weight samples 111/100000
#     Jdev = 0.128007, err = 0.048000
#
# it 111/2000, Jtr_pred = 0.103083, err = 0.031250,    time: 0.387974 seconds
#
#  saving weight samples 112/100000
#     Jdev = 0.136964, err = 0.047000
#
# it 112/2000, Jtr_pred = 0.119574, err = 0.036250,    time: 0.388820 seconds
#
#  saving weight samples 113/100000
#     Jdev = 0.102413, err = 0.032000
#
# it 113/2000, Jtr_pred = 0.113131, err = 0.035000,    time: 0.387264 seconds
#
#  saving weight samples 114/100000
#     Jdev = 0.105256, err = 0.025000
#
# it 114/2000, Jtr_pred = 0.106546, err = 0.026250,    time: 0.387803 seconds
#
#  saving weight samples 115/100000
#     Jdev = 0.098423, err = 0.026000
#
# it 115/2000, Jtr_pred = 0.113265, err = 0.030000,    time: 0.479042 seconds
#
#  saving weight samples 116/100000
#     Jdev = 0.111553, err = 0.035000
#
# it 116/2000, Jtr_pred = 0.118852, err = 0.033750,    time: 0.385770 seconds
#
#  saving weight samples 117/100000
#     Jdev = 0.104800, err = 0.031000
#
# it 117/2000, Jtr_pred = 0.114157, err = 0.038750,    time: 0.386818 seconds
#
#  saving weight samples 118/100000
#     Jdev = 0.111058, err = 0.037000
#
# it 118/2000, Jtr_pred = 0.109126, err = 0.038750,    time: 0.380393 seconds
#
#  saving weight samples 119/100000
#     Jdev = 0.095764, err = 0.030000
#
# it 119/2000, Jtr_pred = 0.107495, err = 0.035000,    time: 0.388510 seconds
#
#  saving weight samples 120/100000
#     Jdev = 0.090408, err = 0.028000
#
# it 120/2000, Jtr_pred = 0.103215, err = 0.036250,    time: 0.387138 seconds
#
#  saving weight samples 121/100000
#     Jdev = 0.098779, err = 0.034000
#
# it 121/2000, Jtr_pred = 0.110347, err = 0.030000,    time: 0.390506 seconds
#
#  saving weight samples 122/100000
#     Jdev = 0.094089, err = 0.022000
#
# it 122/2000, Jtr_pred = 0.106302, err = 0.027500,    time: 0.399985 seconds
#
#  saving weight samples 123/100000
#     Jdev = 0.094453, err = 0.027000
#
# it 123/2000, Jtr_pred = 0.112277, err = 0.040000,    time: 0.380372 seconds
#
#  saving weight samples 124/100000
#     Jdev = 0.083573, err = 0.023000
#
# it 124/2000, Jtr_pred = 0.100033, err = 0.032500,    time: 0.389915 seconds
#
#  saving weight samples 125/100000
#     Jdev = 0.089200, err = 0.025000
#
# it 125/2000, Jtr_pred = 0.100302, err = 0.028750,    time: 0.389507 seconds
#
#  saving weight samples 126/100000
#     Jdev = 0.085173, err = 0.025000
#
# it 126/2000, Jtr_pred = 0.094944, err = 0.025000,    time: 0.385944 seconds
#
#  saving weight samples 127/100000
#     Jdev = 0.083824, err = 0.029000
#
# it 127/2000, Jtr_pred = 0.112853, err = 0.027500,    time: 0.382798 seconds
#
#  saving weight samples 128/100000
#     Jdev = 0.094586, err = 0.027000
#
# it 128/2000, Jtr_pred = 0.106432, err = 0.037500,    time: 0.469270 seconds
#
#  saving weight samples 129/100000
#     Jdev = 0.118422, err = 0.044000
#
# it 129/2000, Jtr_pred = 0.129557, err = 0.041250,    time: 0.393791 seconds
#
#  saving weight samples 130/100000
#     Jdev = 0.117758, err = 0.042000
#
# it 130/2000, Jtr_pred = 0.125736, err = 0.045000,    time: 0.387722 seconds
#
#  saving weight samples 131/100000
#     Jdev = 0.088507, err = 0.027000
#
# it 131/2000, Jtr_pred = 0.104859, err = 0.031250,    time: 0.384746 seconds
#
#  saving weight samples 132/100000
#     Jdev = 0.110515, err = 0.029000
#
# it 132/2000, Jtr_pred = 0.123897, err = 0.036250,    time: 0.390432 seconds
#
#  saving weight samples 133/100000
#     Jdev = 0.113902, err = 0.040000
#
# it 133/2000, Jtr_pred = 0.124511, err = 0.042500,    time: 0.392850 seconds
#
#  saving weight samples 134/100000
#     Jdev = 0.097808, err = 0.024000
#
# it 134/2000, Jtr_pred = 0.104622, err = 0.032500,    time: 0.541167 seconds
#
#  saving weight samples 135/100000
#     Jdev = 0.101277, err = 0.028000
#
# it 135/2000, Jtr_pred = 0.099488, err = 0.032500,    time: 0.386956 seconds
#
#  saving weight samples 136/100000
#     Jdev = 0.085041, err = 0.022000
#
# it 136/2000, Jtr_pred = 0.096071, err = 0.028750,    time: 0.404948 seconds
#
#  saving weight samples 137/100000
#     Jdev = 0.088339, err = 0.024000
#
# it 137/2000, Jtr_pred = 0.092595, err = 0.027500,    time: 0.392135 seconds
#
#  saving weight samples 138/100000
#     Jdev = 0.082586, err = 0.027000
#
# it 138/2000, Jtr_pred = 0.097571, err = 0.036250,    time: 0.384874 seconds
#
#  saving weight samples 139/100000
#     Jdev = 0.076214, err = 0.024000
#
# it 139/2000, Jtr_pred = 0.090856, err = 0.030000,    time: 0.412274 seconds
#
#  saving weight samples 140/100000
#     Jdev = 0.096819, err = 0.033000
#
# it 140/2000, Jtr_pred = 0.100474, err = 0.035000,    time: 0.384883 seconds
#
#  saving weight samples 141/100000
#     Jdev = 0.097864, err = 0.027000
#
# it 141/2000, Jtr_pred = 0.087440, err = 0.028750,    time: 0.386235 seconds
#
#  saving weight samples 142/100000
#     Jdev = 0.078489, err = 0.025000
#
# it 142/2000, Jtr_pred = 0.088758, err = 0.030000,    time: 0.459216 seconds
#
#  saving weight samples 143/100000
#     Jdev = 0.075985, err = 0.022000
#
# it 143/2000, Jtr_pred = 0.094711, err = 0.027500,    time: 0.389366 seconds
#
#  saving weight samples 144/100000
#     Jdev = 0.085888, err = 0.021000
#
# best test error
# it 144/2000, Jtr_pred = 0.092747, err = 0.030000,    time: 0.394424 seconds
#
#  saving weight samples 145/100000
#     Jdev = 0.095843, err = 0.029000
#
# it 145/2000, Jtr_pred = 0.115099, err = 0.033750,    time: 0.390556 seconds
#
#  saving weight samples 146/100000
#     Jdev = 0.085130, err = 0.023000
#
# it 146/2000, Jtr_pred = 0.104530, err = 0.031250,    time: 0.388544 seconds
#
#  saving weight samples 147/100000
#     Jdev = 0.081417, err = 0.026000
#
# it 147/2000, Jtr_pred = 0.096980, err = 0.030000,    time: 0.390894 seconds
#
#  saving weight samples 148/100000
#     Jdev = 0.087205, err = 0.026000
#
# it 148/2000, Jtr_pred = 0.090639, err = 0.025000,    time: 0.391881 seconds
#
#  saving weight samples 149/100000
#     Jdev = 0.080598, err = 0.025000
#
# it 149/2000, Jtr_pred = 0.097576, err = 0.026250,    time: 0.386904 seconds
#
#  saving weight samples 150/100000
#     Jdev = 0.094678, err = 0.029000
#
# it 150/2000, Jtr_pred = 0.108084, err = 0.030000,    time: 0.391849 seconds
#
#  saving weight samples 151/100000
#     Jdev = 0.098095, err = 0.021000
#
# it 151/2000, Jtr_pred = 0.101606, err = 0.026250,    time: 0.388881 seconds
#
#  saving weight samples 152/100000
#     Jdev = 0.083800, err = 0.020000
#
# best test error
# it 152/2000, Jtr_pred = 0.098931, err = 0.023750,    time: 0.387681 seconds
#
#  saving weight samples 153/100000
#     Jdev = 0.082246, err = 0.018000
#
# best test error
# it 153/2000, Jtr_pred = 0.096416, err = 0.023750,    time: 0.388128 seconds
#
#  saving weight samples 154/100000
#     Jdev = 0.102359, err = 0.027000
#
# it 154/2000, Jtr_pred = 0.102060, err = 0.026250,    time: 0.387122 seconds
#
#  saving weight samples 155/100000
#     Jdev = 0.089951, err = 0.024000
#
# it 155/2000, Jtr_pred = 0.102378, err = 0.027500,    time: 0.400247 seconds
#
#  saving weight samples 156/100000
#     Jdev = 0.094131, err = 0.024000
#
# it 156/2000, Jtr_pred = 0.090755, err = 0.026250,    time: 0.386384 seconds
#
#  saving weight samples 157/100000
#     Jdev = 0.094096, err = 0.021000
#
# it 157/2000, Jtr_pred = 0.101229, err = 0.032500,    time: 0.389860 seconds
#
#  saving weight samples 158/100000
#     Jdev = 0.094552, err = 0.024000
#
# it 158/2000, Jtr_pred = 0.101923, err = 0.023750,    time: 0.535425 seconds
#
#  saving weight samples 159/100000
#     Jdev = 0.094784, err = 0.023000
#
# it 159/2000, Jtr_pred = 0.117024, err = 0.031250,    time: 0.390228 seconds
#
#  saving weight samples 160/100000
#     Jdev = 0.101507, err = 0.025000
#
# it 160/2000, Jtr_pred = 0.100702, err = 0.026250,    time: 0.391391 seconds
#
#  saving weight samples 161/100000
#     Jdev = 0.074366, err = 0.015000
#
# best test error
# it 161/2000, Jtr_pred = 0.092476, err = 0.025000,    time: 0.388795 seconds
#
#  saving weight samples 162/100000
#     Jdev = 0.081039, err = 0.024000
#
# it 162/2000, Jtr_pred = 0.124451, err = 0.038750,    time: 0.391829 seconds
#
#  saving weight samples 163/100000
#     Jdev = 0.143049, err = 0.029000
#
# it 163/2000, Jtr_pred = 0.124704, err = 0.032500,    time: 0.391141 seconds
#
#  saving weight samples 164/100000
#     Jdev = 0.131496, err = 0.032000
#
# it 164/2000, Jtr_pred = 0.139689, err = 0.035000,    time: 0.398343 seconds
#
#  saving weight samples 165/100000
#     Jdev = 0.107868, err = 0.024000
#
# it 165/2000, Jtr_pred = 0.129848, err = 0.027500,    time: 0.392853 seconds
#
#  saving weight samples 166/100000
#     Jdev = 0.102305, err = 0.023000
#
# it 166/2000, Jtr_pred = 0.111982, err = 0.027500,    time: 0.382544 seconds
#
#  saving weight samples 167/100000
#     Jdev = 0.102108, err = 0.027000
#
# it 167/2000, Jtr_pred = 0.116738, err = 0.027500,    time: 0.392908 seconds
#
#  saving weight samples 168/100000
#     Jdev = 0.151516, err = 0.038000
#
# it 168/2000, Jtr_pred = 0.103303, err = 0.025000,    time: 0.391549 seconds
#
#  saving weight samples 169/100000
#     Jdev = 0.119425, err = 0.028000
#
# it 169/2000, Jtr_pred = 0.118723, err = 0.033750,    time: 0.392644 seconds
#
#  saving weight samples 170/100000
#     Jdev = 0.101556, err = 0.022000
#
# it 170/2000, Jtr_pred = 0.100100, err = 0.031250,    time: 0.390677 seconds
#
#  saving weight samples 171/100000
#     Jdev = 0.105517, err = 0.023000
#
# it 171/2000, Jtr_pred = 0.168798, err = 0.042500,    time: 0.385567 seconds
#
#  saving weight samples 172/100000
#     Jdev = 0.167857, err = 0.050000
#
# it 172/2000, Jtr_pred = 0.134434, err = 0.038750,    time: 0.392678 seconds
#
#  saving weight samples 173/100000
#     Jdev = 0.095198, err = 0.027000
#
# it 173/2000, Jtr_pred = 0.105325, err = 0.026250,    time: 0.399936 seconds
#
#  saving weight samples 174/100000
#     Jdev = 0.088978, err = 0.027000
#
# it 174/2000, Jtr_pred = 0.103598, err = 0.031250,    time: 0.384593 seconds
#
#  saving weight samples 175/100000
#     Jdev = 0.087628, err = 0.029000
#
# it 175/2000, Jtr_pred = 0.095234, err = 0.027500,    time: 0.387778 seconds
#
#  saving weight samples 176/100000
#     Jdev = 0.089134, err = 0.020000
#
# it 176/2000, Jtr_pred = 0.093845, err = 0.027500,    time: 0.388091 seconds
#
#  saving weight samples 177/100000
#     Jdev = 0.074519, err = 0.016000
#
# it 177/2000, Jtr_pred = 0.089020, err = 0.020000,    time: 0.389106 seconds
#
#  saving weight samples 178/100000
#     Jdev = 0.101863, err = 0.023000
#
# it 178/2000, Jtr_pred = 0.111134, err = 0.027500,    time: 0.385713 seconds
#
#  saving weight samples 179/100000
#     Jdev = 0.087188, err = 0.020000
#
# it 179/2000, Jtr_pred = 0.119904, err = 0.030000,    time: 0.405897 seconds
#
#  saving weight samples 180/100000
#     Jdev = 0.123724, err = 0.027000
#
# it 180/2000, Jtr_pred = 0.110640, err = 0.022500,    time: 0.387410 seconds
#
#  saving weight samples 181/100000
#     Jdev = 0.078472, err = 0.015000
#
# it 181/2000, Jtr_pred = 0.093963, err = 0.025000,    time: 0.399331 seconds
#
#  saving weight samples 182/100000
#     Jdev = 0.085021, err = 0.021000
#
# it 182/2000, Jtr_pred = 0.087749, err = 0.025000,    time: 0.538259 seconds
#
#  saving weight samples 183/100000
#     Jdev = 0.074031, err = 0.019000
#
# it 183/2000, Jtr_pred = 0.080042, err = 0.021250,    time: 0.387019 seconds
#
#  saving weight samples 184/100000
#     Jdev = 0.088336, err = 0.018000
#
# it 184/2000, Jtr_pred = 0.094832, err = 0.021250,    time: 0.389489 seconds
#
#  saving weight samples 185/100000
#     Jdev = 0.086145, err = 0.021000
#
# it 185/2000, Jtr_pred = 0.104006, err = 0.032500,    time: 0.389514 seconds
#
#  saving weight samples 186/100000
#     Jdev = 0.112451, err = 0.036000
#
# it 186/2000, Jtr_pred = 0.097029, err = 0.026250,    time: 0.385087 seconds
#
#  saving weight samples 187/100000
#     Jdev = 0.098076, err = 0.028000
#
# it 187/2000, Jtr_pred = 0.109654, err = 0.035000,    time: 0.405474 seconds
#
#  saving weight samples 188/100000
#     Jdev = 0.098285, err = 0.029000
#
# it 188/2000, Jtr_pred = 0.115693, err = 0.033750,    time: 0.468808 seconds
#
#  saving weight samples 189/100000
#     Jdev = 0.111577, err = 0.032000
#
# it 189/2000, Jtr_pred = 0.128463, err = 0.032500,    time: 0.406497 seconds
#
#  saving weight samples 190/100000
#     Jdev = 0.127004, err = 0.037000
#
# it 190/2000, Jtr_pred = 0.142284, err = 0.046250,    time: 0.401596 seconds
#
#  saving weight samples 191/100000
#     Jdev = 0.135406, err = 0.047000
#
# it 191/2000, Jtr_pred = 0.130209, err = 0.043750,    time: 0.386406 seconds
#
#  saving weight samples 192/100000
#     Jdev = 0.117764, err = 0.040000
#
# it 192/2000, Jtr_pred = 0.114295, err = 0.040000,    time: 0.388470 seconds
#
#  saving weight samples 193/100000
#     Jdev = 0.100409, err = 0.029000
#
# it 193/2000, Jtr_pred = 0.104614, err = 0.030000,    time: 0.387404 seconds
#
#  saving weight samples 194/100000
#     Jdev = 0.094733, err = 0.024000
#
# it 194/2000, Jtr_pred = 0.119250, err = 0.036250,    time: 0.388644 seconds
#
#  saving weight samples 195/100000
#     Jdev = 0.118151, err = 0.039000
#
# it 195/2000, Jtr_pred = 0.118230, err = 0.035000,    time: 0.382449 seconds
#
#  saving weight samples 196/100000
#     Jdev = 0.109180, err = 0.038000
#
# it 196/2000, Jtr_pred = 0.118997, err = 0.036250,    time: 0.385670 seconds
#
#  saving weight samples 197/100000
#     Jdev = 0.100554, err = 0.025000
#
# it 197/2000, Jtr_pred = 0.114309, err = 0.028750,    time: 0.384545 seconds
#
#  saving weight samples 198/100000
#     Jdev = 0.095439, err = 0.029000
#
# it 198/2000, Jtr_pred = 0.105677, err = 0.028750,    time: 0.382652 seconds
#
#  saving weight samples 199/100000
#     Jdev = 0.087822, err = 0.024000
#
# it 199/2000, Jtr_pred = 0.122261, err = 0.038750,    time: 0.382270 seconds
#
#  saving weight samples 200/100000
#     Jdev = 0.098986, err = 0.030000
#
# it 200/2000, Jtr_pred = 0.103230, err = 0.027500,    time: 0.383667 seconds
#
#  saving weight samples 201/100000
#     Jdev = 0.078477, err = 0.026000
#
# it 201/2000, Jtr_pred = 0.090113, err = 0.027500,    time: 0.389215 seconds
#
#  saving weight samples 202/100000
#     Jdev = 0.117027, err = 0.035000
#
# it 202/2000, Jtr_pred = 0.091386, err = 0.023750,    time: 0.382458 seconds
#
#  saving weight samples 203/100000
#     Jdev = 0.076675, err = 0.019000
#
# it 203/2000, Jtr_pred = 0.112102, err = 0.028750,    time: 0.387330 seconds
#
#  saving weight samples 204/100000
#     Jdev = 0.085988, err = 0.025000
#
# it 204/2000, Jtr_pred = 0.115434, err = 0.030000,    time: 0.385857 seconds
#
#  saving weight samples 205/100000
#     Jdev = 0.143567, err = 0.044000
#
# it 205/2000, Jtr_pred = 0.130295, err = 0.033750,    time: 0.387342 seconds
#
#  saving weight samples 206/100000
#     Jdev = 0.080340, err = 0.016000
#
# it 206/2000, Jtr_pred = 0.096551, err = 0.023750,    time: 0.530528 seconds
#
#  saving weight samples 207/100000
#     Jdev = 0.076687, err = 0.022000
#
# it 207/2000, Jtr_pred = 0.097106, err = 0.028750,    time: 0.383994 seconds
#
#  saving weight samples 208/100000
#     Jdev = 0.101886, err = 0.024000
#
# it 208/2000, Jtr_pred = 0.100194, err = 0.028750,    time: 0.383096 seconds
#
#  saving weight samples 209/100000
#     Jdev = 0.090919, err = 0.020000
#
# it 209/2000, Jtr_pred = 0.091841, err = 0.025000,    time: 0.386714 seconds
#
#  saving weight samples 210/100000
#     Jdev = 0.075665, err = 0.021000
#
# it 210/2000, Jtr_pred = 0.088361, err = 0.022500,    time: 0.392397 seconds
#
#  saving weight samples 211/100000
#     Jdev = 0.088787, err = 0.020000
#
# it 211/2000, Jtr_pred = 0.100843, err = 0.028750,    time: 0.384219 seconds
#
#  saving weight samples 212/100000
#     Jdev = 0.089030, err = 0.021000
#
# it 212/2000, Jtr_pred = 0.103620, err = 0.027500,    time: 0.392494 seconds
#
#  saving weight samples 213/100000
#     Jdev = 0.089518, err = 0.022000
#
# it 213/2000, Jtr_pred = 0.097021, err = 0.027500,    time: 0.404861 seconds
#
#  saving weight samples 214/100000
#     Jdev = 0.082021, err = 0.022000
#
# it 214/2000, Jtr_pred = 0.096985, err = 0.025000,    time: 0.401018 seconds
#
#  saving weight samples 215/100000
#     Jdev = 0.087360, err = 0.021000
#
# it 215/2000, Jtr_pred = 0.105155, err = 0.026250,    time: 0.386513 seconds
#
#  saving weight samples 216/100000
#     Jdev = 0.082381, err = 0.023000
#
# it 216/2000, Jtr_pred = 0.101898, err = 0.028750,    time: 0.382576 seconds
#
#  saving weight samples 217/100000
#     Jdev = 0.083716, err = 0.027000
#
# it 217/2000, Jtr_pred = 0.097935, err = 0.030000,    time: 0.385315 seconds
#
#  saving weight samples 218/100000
#     Jdev = 0.085368, err = 0.025000
#
# it 218/2000, Jtr_pred = 0.089699, err = 0.021250,    time: 0.382867 seconds
#
#  saving weight samples 219/100000
#     Jdev = 0.082663, err = 0.017000
#
# it 219/2000, Jtr_pred = 0.089534, err = 0.027500,    time: 0.385811 seconds
#
#  saving weight samples 220/100000
#     Jdev = 0.088955, err = 0.028000
#
# it 220/2000, Jtr_pred = 0.093461, err = 0.028750,    time: 0.385661 seconds
#
#  saving weight samples 221/100000
#     Jdev = 0.085427, err = 0.026000
#
# it 221/2000, Jtr_pred = 0.113479, err = 0.031250,    time: 0.385271 seconds
#
#  saving weight samples 222/100000
#     Jdev = 0.088287, err = 0.027000
#
# it 222/2000, Jtr_pred = 0.103108, err = 0.031250,    time: 0.386228 seconds
#
#  saving weight samples 223/100000
#     Jdev = 0.090433, err = 0.029000
#
# it 223/2000, Jtr_pred = 0.105573, err = 0.028750,    time: 0.386392 seconds
#
#  saving weight samples 224/100000
#     Jdev = 0.099881, err = 0.025000
#
# it 224/2000, Jtr_pred = 0.103083, err = 0.027500,    time: 0.388048 seconds
#
#  saving weight samples 225/100000
#     Jdev = 0.101863, err = 0.030000
#
# it 225/2000, Jtr_pred = 0.114194, err = 0.033750,    time: 0.396214 seconds
#
#  saving weight samples 226/100000
#     Jdev = 0.144266, err = 0.051000
#
# it 226/2000, Jtr_pred = 0.125851, err = 0.040000,    time: 0.403594 seconds
#
#  saving weight samples 227/100000
#     Jdev = 0.095134, err = 0.029000
#
# it 227/2000, Jtr_pred = 0.108062, err = 0.030000,    time: 0.381252 seconds
#
#  saving weight samples 228/100000
#     Jdev = 0.087316, err = 0.025000
#
# it 228/2000, Jtr_pred = 0.096875, err = 0.026250,    time: 0.386733 seconds
#
#  saving weight samples 229/100000
#     Jdev = 0.088888, err = 0.024000
#
# it 229/2000, Jtr_pred = 0.092849, err = 0.031250,    time: 0.380137 seconds
#
#  saving weight samples 230/100000
#     Jdev = 0.086982, err = 0.026000
#
# it 230/2000, Jtr_pred = 0.092319, err = 0.028750,    time: 0.527279 seconds
#
#  saving weight samples 231/100000
#     Jdev = 0.081297, err = 0.026000
#
# it 231/2000, Jtr_pred = 0.105495, err = 0.035000,    time: 0.389383 seconds
#
#  saving weight samples 232/100000
#     Jdev = 0.100391, err = 0.028000
#
# it 232/2000, Jtr_pred = 0.104251, err = 0.031250,    time: 0.386246 seconds
#
#  saving weight samples 233/100000
#     Jdev = 0.088663, err = 0.027000
#
# it 233/2000, Jtr_pred = 0.109971, err = 0.037500,    time: 0.398157 seconds
#
#  saving weight samples 234/100000
#     Jdev = 0.078211, err = 0.022000
#
# it 234/2000, Jtr_pred = 0.100139, err = 0.032500,    time: 0.387401 seconds
#
#  saving weight samples 235/100000
#     Jdev = 0.114107, err = 0.030000
#
# it 235/2000, Jtr_pred = 0.119364, err = 0.042500,    time: 0.383392 seconds
#
#  saving weight samples 236/100000
#     Jdev = 0.105032, err = 0.033000
#
# it 236/2000, Jtr_pred = 0.114526, err = 0.033750,    time: 0.403264 seconds
#
#  saving weight samples 237/100000
#     Jdev = 0.082832, err = 0.028000
#
# it 237/2000, Jtr_pred = 0.103512, err = 0.035000,    time: 0.385793 seconds
#
#  saving weight samples 238/100000
#     Jdev = 0.101716, err = 0.032000
#
# it 238/2000, Jtr_pred = 0.123457, err = 0.038750,    time: 0.387812 seconds
#
#  saving weight samples 239/100000
#     Jdev = 0.130922, err = 0.040000
#
# it 239/2000, Jtr_pred = 0.125203, err = 0.031250,    time: 0.390653 seconds
#
#  saving weight samples 240/100000
#     Jdev = 0.107516, err = 0.029000
#
# it 240/2000, Jtr_pred = 0.126593, err = 0.033750,    time: 0.464651 seconds
#
#  saving weight samples 241/100000
#     Jdev = 0.119143, err = 0.031000
#
# it 241/2000, Jtr_pred = 0.130886, err = 0.040000,    time: 0.442529 seconds
#
#  saving weight samples 242/100000
#     Jdev = 0.154758, err = 0.051000
#
# it 242/2000, Jtr_pred = 0.132841, err = 0.038750,    time: 0.388858 seconds
#
#  saving weight samples 243/100000
#     Jdev = 0.106491, err = 0.026000
#
# it 243/2000, Jtr_pred = 0.115132, err = 0.036250,    time: 0.391717 seconds
#
#  saving weight samples 244/100000
#     Jdev = 0.103047, err = 0.026000
#
# it 244/2000, Jtr_pred = 0.125011, err = 0.031250,    time: 0.458335 seconds
#
#  saving weight samples 245/100000
#     Jdev = 0.097646, err = 0.029000
#
# it 245/2000, Jtr_pred = 0.113968, err = 0.030000,    time: 0.460299 seconds
#
#  saving weight samples 246/100000
#     Jdev = 0.098561, err = 0.024000
#
# it 246/2000, Jtr_pred = 0.108466, err = 0.027500,    time: 0.387719 seconds
#
#  saving weight samples 247/100000
#     Jdev = 0.096090, err = 0.026000
#
# it 247/2000, Jtr_pred = 0.102247, err = 0.028750,    time: 0.475444 seconds
#
#  saving weight samples 248/100000
#     Jdev = 0.097586, err = 0.023000
#
# it 248/2000, Jtr_pred = 0.108260, err = 0.027500,    time: 0.431082 seconds
#
#  saving weight samples 249/100000
#     Jdev = 0.096455, err = 0.027000
#
# it 249/2000, Jtr_pred = 0.111250, err = 0.031250,    time: 0.386772 seconds
#
#  saving weight samples 250/100000
#     Jdev = 0.098104, err = 0.028000
#
# it 250/2000, Jtr_pred = 0.106100, err = 0.028750,    time: 0.387331 seconds
#
#  saving weight samples 251/100000
#     Jdev = 0.091611, err = 0.025000
#
# it 251/2000, Jtr_pred = 0.121107, err = 0.036250,    time: 0.383244 seconds
#
#  saving weight samples 252/100000
#     Jdev = 0.133379, err = 0.034000
#
# it 252/2000, Jtr_pred = 0.121358, err = 0.041250,    time: 0.383810 seconds
#
#  saving weight samples 253/100000
#     Jdev = 0.140847, err = 0.043000
#
# it 253/2000, Jtr_pred = 0.117715, err = 0.037500,    time: 0.409957 seconds
#
#  saving weight samples 254/100000
#     Jdev = 0.108162, err = 0.027000
#
# it 254/2000, Jtr_pred = 0.136123, err = 0.038750,    time: 0.548511 seconds
#
#  saving weight samples 255/100000
#     Jdev = 0.097506, err = 0.031000
#
# it 255/2000, Jtr_pred = 0.106121, err = 0.038750,    time: 0.466285 seconds
#
#  saving weight samples 256/100000
#     Jdev = 0.127275, err = 0.045000
#
# it 256/2000, Jtr_pred = 0.113627, err = 0.037500,    time: 0.443402 seconds
#
#  saving weight samples 257/100000
#     Jdev = 0.108716, err = 0.030000
#
# it 257/2000, Jtr_pred = 0.126413, err = 0.038750,    time: 0.400004 seconds
#
#  saving weight samples 258/100000
#     Jdev = 0.090059, err = 0.027000
#
# it 258/2000, Jtr_pred = 0.104105, err = 0.026250,    time: 0.392363 seconds
#
#  saving weight samples 259/100000
#     Jdev = 0.090060, err = 0.022000
#
# it 259/2000, Jtr_pred = 0.121600, err = 0.041250,    time: 0.388124 seconds
#
#  saving weight samples 260/100000
#     Jdev = 0.128893, err = 0.041000
#
# it 260/2000, Jtr_pred = 0.119218, err = 0.032500,    time: 0.388863 seconds
#
#  saving weight samples 261/100000
#     Jdev = 0.106017, err = 0.032000
#
# it 261/2000, Jtr_pred = 0.117612, err = 0.038750,    time: 0.448147 seconds
#
#  saving weight samples 262/100000
#     Jdev = 0.101292, err = 0.028000
#
# it 262/2000, Jtr_pred = 0.100412, err = 0.030000,    time: 0.387907 seconds
#
#  saving weight samples 263/100000
#     Jdev = 0.084536, err = 0.028000
#
# it 263/2000, Jtr_pred = 0.085629, err = 0.025000,    time: 0.401330 seconds
#
#  saving weight samples 264/100000
#     Jdev = 0.090614, err = 0.025000
#
# it 264/2000, Jtr_pred = 0.093998, err = 0.035000,    time: 0.385399 seconds
#
#  saving weight samples 265/100000
#     Jdev = 0.122266, err = 0.032000
#
# it 265/2000, Jtr_pred = 0.102891, err = 0.028750,    time: 0.432367 seconds
#
#  saving weight samples 266/100000
#     Jdev = 0.110943, err = 0.030000
#
# it 266/2000, Jtr_pred = 0.130064, err = 0.035000,    time: 0.441066 seconds
#
#  saving weight samples 267/100000
#     Jdev = 0.109620, err = 0.036000
#
# it 267/2000, Jtr_pred = 0.113966, err = 0.036250,    time: 0.388080 seconds
#
#  saving weight samples 268/100000
#     Jdev = 0.098149, err = 0.025000
#
# it 268/2000, Jtr_pred = 0.099275, err = 0.025000,    time: 0.450480 seconds
#
#  saving weight samples 269/100000
#     Jdev = 0.117600, err = 0.034000
#
# it 269/2000, Jtr_pred = 0.124313, err = 0.037500,    time: 0.385789 seconds
#
#  saving weight samples 270/100000
#     Jdev = 0.083540, err = 0.026000
#
# it 270/2000, Jtr_pred = 0.091111, err = 0.027500,    time: 0.386902 seconds
#
#  saving weight samples 271/100000
#     Jdev = 0.076451, err = 0.022000
#
# it 271/2000, Jtr_pred = 0.104896, err = 0.031250,    time: 0.387921 seconds
#
#  saving weight samples 272/100000
#     Jdev = 0.094234, err = 0.023000
#
# it 272/2000, Jtr_pred = 0.123596, err = 0.033750,    time: 0.389689 seconds
#
#  saving weight samples 273/100000
#     Jdev = 0.090964, err = 0.024000
#
# it 273/2000, Jtr_pred = 0.135814, err = 0.037500,    time: 0.388966 seconds
#
#  saving weight samples 274/100000
#     Jdev = 0.147036, err = 0.030000
#
# it 274/2000, Jtr_pred = 0.139950, err = 0.032500,    time: 0.388846 seconds
#
#  saving weight samples 275/100000
#     Jdev = 0.116397, err = 0.032000
#
# it 275/2000, Jtr_pred = 0.118823, err = 0.031250,    time: 0.390616 seconds
#
#  saving weight samples 276/100000
#     Jdev = 0.101644, err = 0.030000
#
# it 276/2000, Jtr_pred = 0.105429, err = 0.031250,    time: 0.390429 seconds
#
#  saving weight samples 277/100000
#     Jdev = 0.101480, err = 0.030000
#
# it 277/2000, Jtr_pred = 0.110889, err = 0.033750,    time: 0.389597 seconds
#
#  saving weight samples 278/100000
#     Jdev = 0.090452, err = 0.025000
#
# it 278/2000, Jtr_pred = 0.115058, err = 0.031250,    time: 0.527367 seconds
#
#  saving weight samples 279/100000
#     Jdev = 0.104917, err = 0.031000
#
# it 279/2000, Jtr_pred = 0.115838, err = 0.033750,    time: 0.391592 seconds
#
#  saving weight samples 280/100000
#     Jdev = 0.092883, err = 0.026000
#
# it 280/2000, Jtr_pred = 0.097565, err = 0.025000,    time: 0.394887 seconds
#
#  saving weight samples 281/100000
#     Jdev = 0.077022, err = 0.019000
#
# it 281/2000, Jtr_pred = 0.096531, err = 0.031250,    time: 0.458397 seconds
#
#  saving weight samples 282/100000
#     Jdev = 0.085075, err = 0.022000
#
# it 282/2000, Jtr_pred = 0.095066, err = 0.027500,    time: 0.394732 seconds
#
#  saving weight samples 283/100000
#     Jdev = 0.087763, err = 0.018000
#
# it 283/2000, Jtr_pred = 0.134959, err = 0.046250,    time: 0.392281 seconds
#
#  saving weight samples 284/100000
#     Jdev = 0.117592, err = 0.034000
#
# it 284/2000, Jtr_pred = 0.125864, err = 0.040000,    time: 0.386683 seconds
#
#  saving weight samples 285/100000
#     Jdev = 0.108898, err = 0.032000
#
# it 285/2000, Jtr_pred = 0.126564, err = 0.028750,    time: 0.391743 seconds
#
#  saving weight samples 286/100000
#     Jdev = 0.099955, err = 0.025000
#
# it 286/2000, Jtr_pred = 0.124650, err = 0.031250,    time: 0.391252 seconds
#
#  saving weight samples 287/100000
#     Jdev = 0.141072, err = 0.035000
#
# it 287/2000, Jtr_pred = 0.124542, err = 0.042500,    time: 0.394357 seconds
#
#  saving weight samples 288/100000
#     Jdev = 0.117641, err = 0.034000
#
# it 288/2000, Jtr_pred = 0.117281, err = 0.030000,    time: 0.391292 seconds
#
#  saving weight samples 289/100000
#     Jdev = 0.095512, err = 0.023000
#
# it 289/2000, Jtr_pred = 0.110820, err = 0.035000,    time: 0.385593 seconds
#
#  saving weight samples 290/100000
#     Jdev = 0.108929, err = 0.035000
#
# it 290/2000, Jtr_pred = 0.108232, err = 0.030000,    time: 0.470098 seconds
#
#  saving weight samples 291/100000
#     Jdev = 0.100456, err = 0.026000
#
# it 291/2000, Jtr_pred = 0.135191, err = 0.037500,    time: 0.385717 seconds
#
#  saving weight samples 292/100000
#     Jdev = 0.097949, err = 0.027000
#
# it 292/2000, Jtr_pred = 0.108046, err = 0.027500,    time: 0.400410 seconds
#
#  saving weight samples 293/100000
#     Jdev = 0.107389, err = 0.023000
#
# it 293/2000, Jtr_pred = 0.112845, err = 0.033750,    time: 0.392189 seconds
#
#  saving weight samples 294/100000
#     Jdev = 0.101594, err = 0.026000
#
# it 294/2000, Jtr_pred = 0.125721, err = 0.033750,    time: 0.391173 seconds
#
#  saving weight samples 295/100000
#     Jdev = 0.101942, err = 0.025000
#
# it 295/2000, Jtr_pred = 0.140720, err = 0.032500,    time: 0.382801 seconds
#
#  saving weight samples 296/100000
#     Jdev = 0.094565, err = 0.027000
#
# it 296/2000, Jtr_pred = 0.109318, err = 0.031250,    time: 0.390356 seconds
#
#  saving weight samples 297/100000
#     Jdev = 0.118353, err = 0.042000
#
# it 297/2000, Jtr_pred = 0.106748, err = 0.032500,    time: 0.389485 seconds
#
#  saving weight samples 298/100000
#     Jdev = 0.092830, err = 0.026000
#
# it 298/2000, Jtr_pred = 0.097745, err = 0.028750,    time: 0.400552 seconds
#
#  saving weight samples 299/100000
#     Jdev = 0.092904, err = 0.025000
#
# it 299/2000, Jtr_pred = 0.114534, err = 0.033750,    time: 0.411464 seconds
#
#  saving weight samples 300/100000
#     Jdev = 0.099114, err = 0.026000
#
# it 300/2000, Jtr_pred = 0.116925, err = 0.031250,    time: 0.457200 seconds
#
#  saving weight samples 301/100000
#     Jdev = 0.120635, err = 0.039000
#
# it 301/2000, Jtr_pred = 0.132336, err = 0.040000,    time: 0.385202 seconds
#
#  saving weight samples 302/100000
#     Jdev = 0.095463, err = 0.027000
#
# it 302/2000, Jtr_pred = 0.105117, err = 0.032500,    time: 0.529332 seconds
#
#  saving weight samples 303/100000
#     Jdev = 0.107131, err = 0.028000
#
# it 303/2000, Jtr_pred = 0.120020, err = 0.033750,    time: 0.407486 seconds
#
#  saving weight samples 304/100000
#     Jdev = 0.114520, err = 0.030000
#
# it 304/2000, Jtr_pred = 0.113425, err = 0.031250,    time: 0.385810 seconds
#
#  saving weight samples 305/100000
#     Jdev = 0.104971, err = 0.031000
#
# it 305/2000, Jtr_pred = 0.138365, err = 0.043750,    time: 0.389662 seconds
#
#  saving weight samples 306/100000
#     Jdev = 0.152266, err = 0.041000
#
# it 306/2000, Jtr_pred = 0.133079, err = 0.040000,    time: 0.394633 seconds
#
#  saving weight samples 307/100000
#     Jdev = 0.108309, err = 0.026000
#
# it 307/2000, Jtr_pred = 0.115326, err = 0.035000,    time: 0.387451 seconds
#
#  saving weight samples 308/100000
#     Jdev = 0.092859, err = 0.028000
#
# it 308/2000, Jtr_pred = 0.107387, err = 0.028750,    time: 0.384928 seconds
#
#  saving weight samples 309/100000
#     Jdev = 0.090318, err = 0.023000
#
# it 309/2000, Jtr_pred = 0.113766, err = 0.035000,    time: 0.397572 seconds
#
#  saving weight samples 310/100000
#     Jdev = 0.103048, err = 0.030000
#
# it 310/2000, Jtr_pred = 0.101191, err = 0.031250,    time: 0.383116 seconds
#
#  saving weight samples 311/100000
#     Jdev = 0.088154, err = 0.022000
#
# it 311/2000, Jtr_pred = 0.112523, err = 0.028750,    time: 0.383587 seconds
#
#  saving weight samples 312/100000
#     Jdev = 0.091122, err = 0.027000
#
# it 312/2000, Jtr_pred = 0.102596, err = 0.028750,    time: 0.389538 seconds
#
#  saving weight samples 313/100000
#     Jdev = 0.096585, err = 0.028000
#
# it 313/2000, Jtr_pred = 0.113959, err = 0.035000,    time: 0.387239 seconds
#
#  saving weight samples 314/100000
#     Jdev = 0.102806, err = 0.023000
#
# it 314/2000, Jtr_pred = 0.107956, err = 0.027500,    time: 0.381124 seconds
#
#  saving weight samples 315/100000
#     Jdev = 0.113691, err = 0.034000
#
# it 315/2000, Jtr_pred = 0.113390, err = 0.032500,    time: 0.386173 seconds
#
#  saving weight samples 316/100000
#     Jdev = 0.102130, err = 0.031000
#
# it 316/2000, Jtr_pred = 0.130872, err = 0.042500,    time: 0.391726 seconds
#
#  saving weight samples 317/100000
#     Jdev = 0.165304, err = 0.037000
#
# it 317/2000, Jtr_pred = 0.152957, err = 0.041250,    time: 0.387348 seconds
#
#  saving weight samples 318/100000
#     Jdev = 0.118598, err = 0.031000
#
# it 318/2000, Jtr_pred = 0.112277, err = 0.033750,    time: 0.384876 seconds
#
#  saving weight samples 319/100000
#     Jdev = 0.122044, err = 0.041000
#
# it 319/2000, Jtr_pred = 0.124031, err = 0.035000,    time: 0.380344 seconds
#
#  saving weight samples 320/100000
#     Jdev = 0.110707, err = 0.028000
#
# it 320/2000, Jtr_pred = 0.110763, err = 0.031250,    time: 0.379782 seconds
#
#  saving weight samples 321/100000
#     Jdev = 0.105152, err = 0.029000
#
# it 321/2000, Jtr_pred = 0.122556, err = 0.028750,    time: 0.383602 seconds
#
#  saving weight samples 322/100000
#     Jdev = 0.106690, err = 0.028000
#
# it 322/2000, Jtr_pred = 0.121183, err = 0.037500,    time: 0.401531 seconds
#
#  saving weight samples 323/100000
#     Jdev = 0.100770, err = 0.028000
#
# ...
#
# it 1894/2000, Jtr_pred = 0.111555, err = 0.032500,    time: 0.385776 seconds
#
#  saving weight samples 1895/100000
#     Jdev = 0.090594, err = 0.023000
#
# it 1895/2000, Jtr_pred = 0.106835, err = 0.025000,    time: 0.388295 seconds
#
#  saving weight samples 1896/100000
#     Jdev = 0.086829, err = 0.018000
#
# it 1896/2000, Jtr_pred = 0.093236, err = 0.022500,    time: 0.383382 seconds
#
#  saving weight samples 1897/100000
#     Jdev = 0.080920, err = 0.022000
#
# it 1897/2000, Jtr_pred = 0.107803, err = 0.028750,    time: 0.383153 seconds
#
#  saving weight samples 1898/100000
#     Jdev = 0.091135, err = 0.022000
#
# it 1898/2000, Jtr_pred = 0.101693, err = 0.025000,    time: 0.383218 seconds
#
#  saving weight samples 1899/100000
#     Jdev = 0.086497, err = 0.022000
#
# it 1899/2000, Jtr_pred = 0.102578, err = 0.022500,    time: 0.382647 seconds
#
#  saving weight samples 1900/100000
#     Jdev = 0.094710, err = 0.024000
#
# it 1900/2000, Jtr_pred = 0.116920, err = 0.033750,    time: 0.381474 seconds
#
#  saving weight samples 1901/100000
#     Jdev = 0.098445, err = 0.027000
#
# it 1901/2000, Jtr_pred = 0.110777, err = 0.028750,    time: 0.378748 seconds
#
#  saving weight samples 1902/100000
#     Jdev = 0.093978, err = 0.019000
#
# it 1902/2000, Jtr_pred = 0.109298, err = 0.025000,    time: 0.388985 seconds
#
#  saving weight samples 1903/100000
#     Jdev = 0.116282, err = 0.028000
#
# it 1903/2000, Jtr_pred = 0.119074, err = 0.030000,    time: 0.385087 seconds
#
#  saving weight samples 1904/100000
#     Jdev = 0.103036, err = 0.029000
#
# it 1904/2000, Jtr_pred = 0.111124, err = 0.027500,    time: 0.393302 seconds
#
#  saving weight samples 1905/100000
#     Jdev = 0.133546, err = 0.026000
#
# it 1905/2000, Jtr_pred = 0.096327, err = 0.023750,    time: 0.383500 seconds
#
#  saving weight samples 1906/100000
#     Jdev = 0.088838, err = 0.023000
#
# it 1906/2000, Jtr_pred = 0.113841, err = 0.028750,    time: 0.533245 seconds
#
#  saving weight samples 1907/100000
#     Jdev = 0.101337, err = 0.020000
#
# it 1907/2000, Jtr_pred = 0.106462, err = 0.030000,    time: 0.383910 seconds
#
#  saving weight samples 1908/100000
#     Jdev = 0.095875, err = 0.025000
#
# it 1908/2000, Jtr_pred = 0.099941, err = 0.023750,    time: 0.384747 seconds
#
#  saving weight samples 1909/100000
#     Jdev = 0.107636, err = 0.029000
#
# it 1909/2000, Jtr_pred = 0.124691, err = 0.041250,    time: 0.386708 seconds
#
#  saving weight samples 1910/100000
#     Jdev = 0.167473, err = 0.065000
#
# it 1910/2000, Jtr_pred = 0.126831, err = 0.040000,    time: 0.389752 seconds
#
#  saving weight samples 1911/100000
#     Jdev = 0.107217, err = 0.026000
#
# it 1911/2000, Jtr_pred = 0.114025, err = 0.028750,    time: 0.445654 seconds
#
#  saving weight samples 1912/100000
#     Jdev = 0.106003, err = 0.031000
#
# it 1912/2000, Jtr_pred = 0.110248, err = 0.033750,    time: 0.399456 seconds
#
#  saving weight samples 1913/100000
#     Jdev = 0.106890, err = 0.031000
#
# it 1913/2000, Jtr_pred = 0.111782, err = 0.031250,    time: 0.387085 seconds
#
#  saving weight samples 1914/100000
#     Jdev = 0.103139, err = 0.029000
#
# it 1914/2000, Jtr_pred = 0.113324, err = 0.033750,    time: 0.388525 seconds
#
#  saving weight samples 1915/100000
#     Jdev = 0.099185, err = 0.025000
#
# it 1915/2000, Jtr_pred = 0.115456, err = 0.030000,    time: 0.398352 seconds
#
#  saving weight samples 1916/100000
#     Jdev = 0.105462, err = 0.031000
#
# it 1916/2000, Jtr_pred = 0.124351, err = 0.033750,    time: 0.386478 seconds
#
#  saving weight samples 1917/100000
#     Jdev = 0.113871, err = 0.032000
#
# it 1917/2000, Jtr_pred = 0.115472, err = 0.031250,    time: 0.389054 seconds
#
#  saving weight samples 1918/100000
#     Jdev = 0.107019, err = 0.030000
#
# it 1918/2000, Jtr_pred = 0.138794, err = 0.033750,    time: 0.376796 seconds
#
#  saving weight samples 1919/100000
#     Jdev = 0.116958, err = 0.030000
#
# it 1919/2000, Jtr_pred = 0.127834, err = 0.033750,    time: 0.382367 seconds
#
#  saving weight samples 1920/100000
#     Jdev = 0.104594, err = 0.026000
#
# it 1920/2000, Jtr_pred = 0.118056, err = 0.028750,    time: 0.378701 seconds
#
#  saving weight samples 1921/100000
#     Jdev = 0.104501, err = 0.026000
#
# it 1921/2000, Jtr_pred = 0.115418, err = 0.028750,    time: 0.385311 seconds
#
#  saving weight samples 1922/100000
#     Jdev = 0.105601, err = 0.024000
#
# it 1922/2000, Jtr_pred = 0.106456, err = 0.028750,    time: 0.389071 seconds
#
#  saving weight samples 1923/100000
#     Jdev = 0.092549, err = 0.024000
#
# it 1923/2000, Jtr_pred = 0.102542, err = 0.028750,    time: 0.393356 seconds
#
#  saving weight samples 1924/100000
#     Jdev = 0.084807, err = 0.023000
#
# it 1924/2000, Jtr_pred = 0.097938, err = 0.027500,    time: 0.384957 seconds
#
#  saving weight samples 1925/100000
#     Jdev = 0.093203, err = 0.024000
#
# it 1925/2000, Jtr_pred = 0.106464, err = 0.031250,    time: 0.389344 seconds
#
#  saving weight samples 1926/100000
#     Jdev = 0.089715, err = 0.023000
#
# it 1926/2000, Jtr_pred = 0.112588, err = 0.028750,    time: 0.383916 seconds
#
#  saving weight samples 1927/100000
#     Jdev = 0.087814, err = 0.023000
#
# it 1927/2000, Jtr_pred = 0.130122, err = 0.033750,    time: 0.383836 seconds
#
#  saving weight samples 1928/100000
#     Jdev = 0.100150, err = 0.023000
#
# it 1928/2000, Jtr_pred = 0.098151, err = 0.031250,    time: 0.386837 seconds
#
#  saving weight samples 1929/100000
#     Jdev = 0.094603, err = 0.026000
#
# it 1929/2000, Jtr_pred = 0.093026, err = 0.021250,    time: 0.393810 seconds
#
#  saving weight samples 1930/100000
#     Jdev = 0.086109, err = 0.027000
#
# it 1930/2000, Jtr_pred = 0.099767, err = 0.030000,    time: 0.390024 seconds
#
#  saving weight samples 1931/100000
#     Jdev = 0.092253, err = 0.021000
#
# it 1931/2000, Jtr_pred = 0.104567, err = 0.030000,    time: 0.536699 seconds
#
#  saving weight samples 1932/100000
#     Jdev = 0.094403, err = 0.029000
#
# it 1932/2000, Jtr_pred = 0.094551, err = 0.031250,    time: 0.398393 seconds
#
#  saving weight samples 1933/100000
#     Jdev = 0.088487, err = 0.023000
#
# it 1933/2000, Jtr_pred = 0.105685, err = 0.030000,    time: 0.384449 seconds
#
#  saving weight samples 1934/100000
#     Jdev = 0.141880, err = 0.035000
#
# it 1934/2000, Jtr_pred = 0.125675, err = 0.036250,    time: 0.399814 seconds
#
#  saving weight samples 1935/100000
#     Jdev = 0.091665, err = 0.027000
#
# it 1935/2000, Jtr_pred = 0.107669, err = 0.032500,    time: 0.383551 seconds
#
#  saving weight samples 1936/100000
#     Jdev = 0.096634, err = 0.030000
#
# it 1936/2000, Jtr_pred = 0.114212, err = 0.032500,    time: 0.383040 seconds
#
#  saving weight samples 1937/100000
#     Jdev = 0.097941, err = 0.032000
#
# it 1937/2000, Jtr_pred = 0.112252, err = 0.033750,    time: 0.386587 seconds
#
#  saving weight samples 1938/100000
#     Jdev = 0.096290, err = 0.028000
#
# it 1938/2000, Jtr_pred = 0.103373, err = 0.032500,    time: 0.388737 seconds
#
#  saving weight samples 1939/100000
#     Jdev = 0.101360, err = 0.028000
#
# it 1939/2000, Jtr_pred = 0.110809, err = 0.027500,    time: 0.386288 seconds
#
#  saving weight samples 1940/100000
#     Jdev = 0.104770, err = 0.024000
#
# it 1940/2000, Jtr_pred = 0.094571, err = 0.030000,    time: 0.394403 seconds
#
#  saving weight samples 1941/100000
#     Jdev = 0.084587, err = 0.025000
#
# it 1941/2000, Jtr_pred = 0.093527, err = 0.028750,    time: 0.384796 seconds
#
#  saving weight samples 1942/100000
#     Jdev = 0.085597, err = 0.025000
#
# it 1942/2000, Jtr_pred = 0.096005, err = 0.030000,    time: 0.384949 seconds
#
#  saving weight samples 1943/100000
#     Jdev = 0.087774, err = 0.026000
#
# it 1943/2000, Jtr_pred = 0.108841, err = 0.025000,    time: 0.381195 seconds
#
#  saving weight samples 1944/100000
#     Jdev = 0.093169, err = 0.022000
#
# it 1944/2000, Jtr_pred = 0.099248, err = 0.026250,    time: 0.383745 seconds
#
#  saving weight samples 1945/100000
#     Jdev = 0.082845, err = 0.021000
#
# it 1945/2000, Jtr_pred = 0.114357, err = 0.027500,    time: 0.383628 seconds
#
#  saving weight samples 1946/100000
#     Jdev = 0.087842, err = 0.027000
#
# it 1946/2000, Jtr_pred = 0.102322, err = 0.021250,    time: 0.380331 seconds
#
#  saving weight samples 1947/100000
#     Jdev = 0.097353, err = 0.017000
#
# it 1947/2000, Jtr_pred = 0.114781, err = 0.037500,    time: 0.464759 seconds
#
#  saving weight samples 1948/100000
#     Jdev = 0.095895, err = 0.029000
#
# it 1948/2000, Jtr_pred = 0.110690, err = 0.033750,    time: 0.399261 seconds
#
#  saving weight samples 1949/100000
#     Jdev = 0.110285, err = 0.022000
#
# it 1949/2000, Jtr_pred = 0.147543, err = 0.043750,    time: 0.377302 seconds
#
#  saving weight samples 1950/100000
#     Jdev = 0.125660, err = 0.032000
#
# it 1950/2000, Jtr_pred = 0.133291, err = 0.038750,    time: 0.386023 seconds
#
#  saving weight samples 1951/100000
#     Jdev = 0.112976, err = 0.034000
#
# it 1951/2000, Jtr_pred = 0.131515, err = 0.038750,    time: 0.381459 seconds
#
#  saving weight samples 1952/100000
#     Jdev = 0.127866, err = 0.033000
#
# it 1952/2000, Jtr_pred = 0.119342, err = 0.033750,    time: 0.381144 seconds
#
#  saving weight samples 1953/100000
#     Jdev = 0.117683, err = 0.035000
#
# it 1953/2000, Jtr_pred = 0.108778, err = 0.032500,    time: 0.381870 seconds
#
#  saving weight samples 1954/100000
#     Jdev = 0.141306, err = 0.043000
#
# it 1954/2000, Jtr_pred = 0.140033, err = 0.035000,    time: 0.382811 seconds
#
#  saving weight samples 1955/100000
#     Jdev = 0.097698, err = 0.029000
#
# it 1955/2000, Jtr_pred = 0.105169, err = 0.032500,    time: 0.384824 seconds
#
#  saving weight samples 1956/100000
#     Jdev = 0.122585, err = 0.033000
#
# it 1956/2000, Jtr_pred = 0.126008, err = 0.036250,    time: 0.594876 seconds
#
#  saving weight samples 1957/100000
#     Jdev = 0.104129, err = 0.030000
#
# it 1957/2000, Jtr_pred = 0.107524, err = 0.027500,    time: 0.419973 seconds
#
#  saving weight samples 1958/100000
#     Jdev = 0.098246, err = 0.026000
#
# it 1958/2000, Jtr_pred = 0.105006, err = 0.027500,    time: 0.439719 seconds
#
#  saving weight samples 1959/100000
#     Jdev = 0.095694, err = 0.023000
#
# it 1959/2000, Jtr_pred = 0.112136, err = 0.032500,    time: 0.378591 seconds
#
#  saving weight samples 1960/100000
#     Jdev = 0.092914, err = 0.024000
#
# it 1960/2000, Jtr_pred = 0.102426, err = 0.028750,    time: 0.381743 seconds
#
#  saving weight samples 1961/100000
#     Jdev = 0.085089, err = 0.025000
#
# it 1961/2000, Jtr_pred = 0.112711, err = 0.032500,    time: 0.386687 seconds
#
#  saving weight samples 1962/100000
#     Jdev = 0.137981, err = 0.031000
#
# it 1962/2000, Jtr_pred = 0.118734, err = 0.027500,    time: 0.387232 seconds
#
#  saving weight samples 1963/100000
#     Jdev = 0.096736, err = 0.027000
#
# it 1963/2000, Jtr_pred = 0.102988, err = 0.032500,    time: 0.384587 seconds
#
#  saving weight samples 1964/100000
#     Jdev = 0.079985, err = 0.020000
#
# it 1964/2000, Jtr_pred = 0.106123, err = 0.027500,    time: 0.384752 seconds
#
#  saving weight samples 1965/100000
#     Jdev = 0.089479, err = 0.024000
#
# it 1965/2000, Jtr_pred = 0.104478, err = 0.028750,    time: 0.385224 seconds
#
#  saving weight samples 1966/100000
#     Jdev = 0.085280, err = 0.020000
#
# it 1966/2000, Jtr_pred = 0.086355, err = 0.023750,    time: 0.386771 seconds
#
#  saving weight samples 1967/100000
#     Jdev = 0.087993, err = 0.021000
#
# it 1967/2000, Jtr_pred = 0.093127, err = 0.026250,    time: 0.384460 seconds
#
#  saving weight samples 1968/100000
#     Jdev = 0.076127, err = 0.016000
#
# it 1968/2000, Jtr_pred = 0.079943, err = 0.025000,    time: 0.382871 seconds
#
#  saving weight samples 1969/100000
#     Jdev = 0.075065, err = 0.018000
#
# it 1969/2000, Jtr_pred = 0.101268, err = 0.032500,    time: 0.379995 seconds
#
#  saving weight samples 1970/100000
#     Jdev = 0.092983, err = 0.024000
#
# it 1970/2000, Jtr_pred = 0.109604, err = 0.030000,    time: 0.397829 seconds
#
#  saving weight samples 1971/100000
#     Jdev = 0.095664, err = 0.025000
#
# it 1971/2000, Jtr_pred = 0.103867, err = 0.035000,    time: 0.382941 seconds
#
#  saving weight samples 1972/100000
#     Jdev = 0.156931, err = 0.053000
#
# it 1972/2000, Jtr_pred = 0.107934, err = 0.028750,    time: 0.386735 seconds
#
#  saving weight samples 1973/100000
#     Jdev = 0.090521, err = 0.019000
#
# it 1973/2000, Jtr_pred = 0.079719, err = 0.018750,    time: 0.383505 seconds
#
#  saving weight samples 1974/100000
#     Jdev = 0.094372, err = 0.023000
#
# it 1974/2000, Jtr_pred = 0.096080, err = 0.026250,    time: 0.388162 seconds
#
#  saving weight samples 1975/100000
#     Jdev = 0.082910, err = 0.023000
#
# it 1975/2000, Jtr_pred = 0.102902, err = 0.025000,    time: 0.400972 seconds
#
#  saving weight samples 1976/100000
#     Jdev = 0.079292, err = 0.016000
#
# it 1976/2000, Jtr_pred = 0.069427, err = 0.016250,    time: 0.387541 seconds
#
#  saving weight samples 1977/100000
#     Jdev = 0.091671, err = 0.022000
#
# it 1977/2000, Jtr_pred = 0.096770, err = 0.027500,    time: 0.397180 seconds
#
#  saving weight samples 1978/100000
#     Jdev = 0.070613, err = 0.021000
#
# it 1978/2000, Jtr_pred = 0.093238, err = 0.026250,    time: 0.380852 seconds
#
#  saving weight samples 1979/100000
#     Jdev = 0.087880, err = 0.021000
#
# it 1979/2000, Jtr_pred = 0.114340, err = 0.026250,    time: 0.383774 seconds
#
#  saving weight samples 1980/100000
#     Jdev = 0.115530, err = 0.035000
#
# it 1980/2000, Jtr_pred = 0.091920, err = 0.023750,    time: 0.380520 seconds
#
#  saving weight samples 1981/100000
#     Jdev = 0.065555, err = 0.015000
#
# it 1981/2000, Jtr_pred = 0.087621, err = 0.022500,    time: 0.542545 seconds
#
#  saving weight samples 1982/100000
#     Jdev = 0.073549, err = 0.019000
#
# it 1982/2000, Jtr_pred = 0.077844, err = 0.021250,    time: 0.383746 seconds
#
#  saving weight samples 1983/100000
#     Jdev = 0.067714, err = 0.017000
#
# it 1983/2000, Jtr_pred = 0.093132, err = 0.023750,    time: 0.384157 seconds
#
#  saving weight samples 1984/100000
#     Jdev = 0.119101, err = 0.036000
#
# it 1984/2000, Jtr_pred = 0.100133, err = 0.027500,    time: 0.383122 seconds
#
#  saving weight samples 1985/100000
#     Jdev = 0.234344, err = 0.102000
#
# it 1985/2000, Jtr_pred = 0.128108, err = 0.037500,    time: 0.383536 seconds
#
#  saving weight samples 1986/100000
#     Jdev = 0.109551, err = 0.029000
#
# it 1986/2000, Jtr_pred = 0.110874, err = 0.035000,    time: 0.382934 seconds
#
#  saving weight samples 1987/100000
#     Jdev = 0.111814, err = 0.032000
#
# it 1987/2000, Jtr_pred = 0.114889, err = 0.036250,    time: 0.388372 seconds
#
#  saving weight samples 1988/100000
#     Jdev = 0.092779, err = 0.027000
#
# it 1988/2000, Jtr_pred = 0.102271, err = 0.028750,    time: 0.388241 seconds
#
#  saving weight samples 1989/100000
#     Jdev = 0.089588, err = 0.025000
#
# it 1989/2000, Jtr_pred = 0.108131, err = 0.028750,    time: 0.412611 seconds
#
#  saving weight samples 1990/100000
#     Jdev = 0.115923, err = 0.032000
#
# it 1990/2000, Jtr_pred = 0.111007, err = 0.035000,    time: 0.388598 seconds
#
#  saving weight samples 1991/100000
#     Jdev = 0.084264, err = 0.027000
#
# it 1991/2000, Jtr_pred = 0.078893, err = 0.026250,    time: 0.399441 seconds
#
#  saving weight samples 1992/100000
#     Jdev = 0.077027, err = 0.026000
#
# it 1992/2000, Jtr_pred = 0.087090, err = 0.025000,    time: 0.382676 seconds
#
#  saving weight samples 1993/100000
#     Jdev = 0.098111, err = 0.029000
#
# it 1993/2000, Jtr_pred = 0.129310, err = 0.038750,    time: 0.393171 seconds
#
#  saving weight samples 1994/100000
#     Jdev = 0.098396, err = 0.027000
#
# it 1994/2000, Jtr_pred = 0.106093, err = 0.030000,    time: 0.385565 seconds
#
#  saving weight samples 1995/100000
#     Jdev = 0.108825, err = 0.028000
#
# it 1995/2000, Jtr_pred = 0.103617, err = 0.030000,    time: 0.387148 seconds
#
#  saving weight samples 1996/100000
#     Jdev = 0.090401, err = 0.022000
#
# it 1996/2000, Jtr_pred = 0.103685, err = 0.027500,    time: 0.382423 seconds
#
#  saving weight samples 1997/100000
#     Jdev = 0.076351, err = 0.019000
#
# it 1997/2000, Jtr_pred = 0.106194, err = 0.031250,    time: 0.383215 seconds
#
#  saving weight samples 1998/100000
#     Jdev = 0.102300, err = 0.025000
#
# it 1998/2000, Jtr_pred = 0.108200, err = 0.030000,    time: 0.384182 seconds
#
#  saving weight samples 1999/100000
#     Jdev = 0.098377, err = 0.026000
#
# it 1999/2000, Jtr_pred = 0.128767, err = 0.033750,    time: 0.396415 seconds
#
#  saving weight samples 2000/100000
#     Jdev = 0.107464, err = 0.029000
#
#    average time: 0.584913 seconds
#
#    total time: 1169.826573 seconds

# %%
import numpy as np

# Assuming y_hat is your original (10, 1000) array
threshold = 0.5
y_hat_thresholded = np.where(probs >= threshold, 1, 0)
save_object(y_hat_thresholded, models_dir + '/yhats.pkl')

# %%
# save result
with open('./SGHMC_models/calibration_bnn.pickle','wb') as f:
    pickle.dump([init_state, state_dicts, yhats, probs],f)
# load result
with open(os.path.join('./SGHMC_models/calibration_bnn.pickle'), 'rb') as f:
  [init_weights, state_dicts, yhats, ps] = pickle.load(f)
init_weights.shape, yhats.shape, ps.shape
# Out:
# ((56,), (2000, 1000), (2000, 1000))

# %%
np.mean(test_accuracy_dev)
# Out:
# 0.9601675000000001
